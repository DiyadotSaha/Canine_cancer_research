# %%
# !pip install -q Llama-parse
# !pip install -q llama-index
# !pip install -q nest-asyncio
# !pip install -q pdfminer.six

# %%
from pdfminer.high_level import extract_text
#from llama_parse import LlamaParse
import os
import nest_asyncio
import pandas as pd
import re
import csv
from io import StringIO

# %% [markdown]
# #### 1. To grab all the .pdf files from the given directory

# %%
def process_pdfs_in_directory(dir_path):
    """
    Processes the specified number of .pdf files in the given directory by parsing and saving them as CSVs.
    Args:
    dir_path (str): The path to the directory containing .pdf files.
    
    """
    files = os.listdir(dir_path)
    list_files = []
    pdf_files = [f for f in files if f.endswith('.pdf')]
    pdf_count = 0
    for pdf_file in pdf_files:
        pdf_count+=1
        file_path = os.path.join(dir_path, pdf_file)
        file_name = os.path.splitext(pdf_file)[0]
        list_files += [(file_path, file_name)]
    print("Total num of pdfsS: ", pdf_count)
    return list_files

# %% [markdown]
# #### 2. Extract the text from a given pdf (including removing footer text)

# %%
def extract_text_from_pdf(pdf_path, start_marker, end_marker):
    text = extract_text(pdf_path)
    start_pos = text.find(start_marker)
    end_pos = text.find(end_marker, start_pos)
    if start_pos == -1 or end_pos == -1:
        return None
    extracted_text = text[start_pos:end_pos + len(end_marker)]
    cleaned_text = re.sub(r'.*Vidium.*Toll-Free: 833-794-0318.*\n', '', extracted_text)
    cleaned_text = re.sub(r'Page\s+\d+\s+of\s+\d+\s*\n', '', cleaned_text)
    cleaned_text = re.sub(r'SearchLight DNA Clinician Report\s*', '', cleaned_text)
    cleaned_text = re.sub(r'Detailed Summary:\n', '', cleaned_text)
    cleaned_text = re.sub(r'Please see Link for a detailed summary of this gene as well as information regarding this variant and its associated canine and human data.\n', '', cleaned_text)
    return cleaned_text

# %% [markdown]
# #### 3. Convert the text into sensible chunks

# %%
def text_chunking(text):
    if text is None: 
        return None 
    gene_sections = text.split("\n\n")
    chunks = []
    chunk = ""
    marker_pattern = r"Variant Summary:\n\n.*?\n\n"
    link_info_pattern = r'Please see Link for a detailed summary of this gene as well as information regarding this variant and its associated \ncanine and human data.'
    for section in gene_sections:
        if section.strip():  
            chunk += section + "\n\n"
            marker_match = re.search(marker_pattern, chunk, re.DOTALL)
            if marker_match:
                end_marker_index = marker_match.end()
                cleaned_chunk = re.sub(link_info_pattern, '', chunk[:end_marker_index].strip(), flags=re.DOTALL)
                
                chunks.append(cleaned_chunk.strip())
                chunk = chunk[end_marker_index:].strip() + "\n\n"
    if chunk.strip():
        chunks.append(chunk.strip())
    return chunks

# %% [markdown]
# #### 4. Extract mutation summary information from the given text chunk

# %%
def extract_gene_info(chunk):
    #print("Input Chunk:\n", chunk)
    #print("\n----------------------------------------------\n")
    #gene
    gene_match = re.search(r"Gene\s*\n\s*(.*?)\n", chunk, re.DOTALL)
    if not gene_match:
        return None
    gene = gene_match.group(1).strip()
    gene = {'gene':gene,'mutation':'', 'roles':'', 'variant_summary':''}
    # Mutation
    mutation_match = re.search(r"Mutation\s*\n\s*(.*?)\n", chunk, re.DOTALL)
    if mutation_match:
        mutation = mutation_match.group(1).strip()
        gene['mutation'] = mutation
        #print(f"EXTRACTED Mutation: {mutation}")
    
    # Roles in the case
    roles_match = re.search(r"Roles in this case:\s*\n\s*(.*?)\s*Variant Summary:", chunk, re.DOTALL)
    if roles_match:
        roles = roles_match.group(1).strip()
        #print(f"EXTRACTED Roles in this case: {roles}")
    else:
        roles = ""
    gene['roles'] = roles
    
    variant_match = re.search(r"Variant Summary:\s*\n\s*(.*?)(?=\n\n|$)", chunk, re.DOTALL)
    if variant_match:
        variant_summary = variant_match.group(1).strip()
        #print(f"EXTRACTED Variant Summary: {variant_summary}")
    else:
        variant_summary = ""
    gene['variant_summary'] = variant_summary
    return gene

# %% [markdown]
# #### 5. Creating the .csv for current file being processed

# %%
def mutation_csv(gene_dictionary, file_name):
    output_dir = f"{file_name}_clinical_report"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        
    csv_file_path = os.path.join(output_dir, f"{file_name}_mutsumm.csv")
    headers = ['gene', 'mutation', 'roles', 'variant_summary']
    
    with open(csv_file_path, mode='w', newline='') as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames=headers)
        writer.writeheader()
        for key, value in gene_dictionary.items():
            writer.writerow(value)
    print(f"CSV file created at: {csv_file_path}\n")
    output_file = file_name.replace(".csv", "_with_cancers.csv")
    df.to_csv(output_file, index=False)
    return df

# Example usage
file_name = "your_input_file.csv"
df_with_cancers = ner_cancer(file_name)
print(df_with_cancers)

# %% [markdown]
# #### 6. NER cancer types

# %%
def ner_cancer(file_name):
    df = pd.read_csv(file_name)
    if 'variant_summary' not in df.columns:
        raise ValueError("The input file must contain a 'variant_summary' column.")
    def extract_cancers(text):
        doc = nlp(text)
        cancers = [ent.text for ent in doc.ents if ent.label_ == 'DISEASE']
        return cancers

    df['cancers'] = df['variant'].apply(lambda x: extract_cancers(x) if pd.notnull(x) else [])

# %%
print("DONE!!!")
# Out:
# DONE!!!

# %%
output_dir = 'Searchlight Info/SearchlightReports'
file_list = process_pdfs_in_directory(output_dir)

start_marker = "Mutation Summaries"
end_marker = "Clinical Trials Summary"

for i in file_list: 
    f_path = i[0]
    f_name = i[1]
    print('file name: ', f_name, " file_path: ", f_path, " \n")
    pdf_text_between_markers = extract_text_from_pdf(f_path, start_marker, end_marker)
    mutation_chunks = text_chunking(pdf_text_between_markers)
    temp_gene_dictionary = {}
    gene_counter = 0
    if mutation_chunks is None:
        print(f"File {f_name} at {f_path} skipped (lack of information).")
    else:
        temp_gene_dictionary = {}
        gene_counter = 0
        for i, chunk in enumerate(mutation_chunks):
            #print(f"Chunk {i + 1}:-\n{chunk}\n")
            #print("\n---------------------------------------\n")
            dictionary_gene = extract_gene_info(chunk)
            if dictionary_gene is not None: 
                temp_gene_dictionary[gene_counter] = dictionary_gene
                gene_counter += 1
        mutation_csv(temp_gene_dictionary, f_name)
# Out:
# Total num of pdfsS:  1012
# file name:  SL23-000862_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000862_1_371.pdf
#
# CSV file created at: SL23-000862_1_371_clinical_report/SL23-000862_1_371_mutsumm.csv
#
# file name:  SL23-000579_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000579_1_371.pdf
#
# CSV file created at: SL23-000579_1_371_clinical_report/SL23-000579_1_371_mutsumm.csv
#
# file name:  SL23-000609_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000609_1_371.pdf
#
# CSV file created at: SL23-000609_1_371_clinical_report/SL23-000609_1_371_mutsumm.csv
#
# file name:  SL23-000924_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000924_1_371.pdf
#
# CSV file created at: SL23-000924_1_371_clinical_report/SL23-000924_1_371_mutsumm.csv
#
# file name:  SL24-000182_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000182_1_371.pdf
#
# CSV file created at: SL24-000182_1_371_clinical_report/SL24-000182_1_371_mutsumm.csv
#
# file name:  SL23-001055_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001055_1_371.pdf
#
# CSV file created at: SL23-001055_1_371_clinical_report/SL23-001055_1_371_mutsumm.csv
#
# file name:  SL23-000187_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000187_1_370.pdf
#
# CSV file created at: SL23-000187_1_370_clinical_report/SL23-000187_1_370_mutsumm.csv
#
# file name:  SL23-000464_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000464_1_370.pdf
#
# CSV file created at: SL23-000464_1_370_clinical_report/SL23-000464_1_370_mutsumm.csv
#
# file name:  SL23-000673_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000673_1_371.pdf
#
# CSV file created at: SL23-000673_1_371_clinical_report/SL23-000673_1_371_mutsumm.csv
#
# file name:  SL23-000997_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000997_1_371.pdf
#
# CSV file created at: SL23-000997_1_371_clinical_report/SL23-000997_1_371_mutsumm.csv
#
# file name:  SL23-000735_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000735_1_371.pdf
#
# CSV file created at: SL23-000735_1_371_clinical_report/SL23-000735_1_371_mutsumm.csv
#
# file name:  SL23-000818_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000818_1_371.pdf
#
# CSV file created at: SL23-000818_1_371_clinical_report/SL23-000818_1_371_mutsumm.csv
#
# file name:  SL23-000302_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000302_1_370.pdf
#
# CSV file created at: SL23-000302_1_370_clinical_report/SL23-000302_1_370_mutsumm.csv
#
# file name:  SL23-000134_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000134_1_370.pdf
#
# CSV file created at: SL23-000134_1_370_clinical_report/SL23-000134_1_370_mutsumm.csv
#
# file name:  SL24-000077_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000077_1_371.pdf
#
# CSV file created at: SL24-000077_1_371_clinical_report/SL24-000077_1_371_mutsumm.csv
#
# file name:  SL23-000244_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000244_1_370.pdf
#
# CSV file created at: SL23-000244_1_370_clinical_report/SL23-000244_1_370_mutsumm.csv
#
# file name:  SL24-000131_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000131_1_371.pdf
#
# CSV file created at: SL24-000131_1_371_clinical_report/SL24-000131_1_371_mutsumm.csv
#
# file name:  SL24-000125_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000125_1_371.pdf
#
# CSV file created at: SL24-000125_1_371_clinical_report/SL24-000125_1_371_mutsumm.csv
#
# file name:  SL23-000299_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000299_1_370.pdf
#
# CSV file created at: SL23-000299_1_370_clinical_report/SL23-000299_1_370_mutsumm.csv
#
# file name:  SL23-000120_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000120_1_370.pdf
#
# CSV file created at: SL23-000120_1_370_clinical_report/SL23-000120_1_370_mutsumm.csv
#
# file name:  SL24-000063_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000063_1_371.pdf
#
# CSV file created at: SL24-000063_1_371_clinical_report/SL24-000063_1_371_mutsumm.csv
#
# file name:  SL24-000255_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000255_1_371.pdf
#
# CSV file created at: SL24-000255_1_371_clinical_report/SL24-000255_1_371_mutsumm.csv
#
# file name:  SL23-000721_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000721_1_371.pdf
#
# CSV file created at: SL23-000721_1_371_clinical_report/SL23-000721_1_371_mutsumm.csv
#
# file name:  SL23-000983_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000983_1_371.pdf
#
# CSV file created at: SL23-000983_1_371_clinical_report/SL23-000983_1_371_mutsumm.csv
#
# file name:  SL23-000667_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000667_1_371.pdf
#
# CSV file created at: SL23-000667_1_371_clinical_report/SL23-000667_1_371_mutsumm.csv
#
# file name:  SL23-000470_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000470_1_370.pdf
#
# CSV file created at: SL23-000470_1_370_clinical_report/SL23-000470_1_370_mutsumm.csv
#
# file name:  SL24-000019_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000019_1_371.pdf
#
# CSV file created at: SL24-000019_1_371_clinical_report/SL24-000019_1_371_mutsumm.csv
#
# file name:  SL23-001041_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001041_1_371.pdf
#
# CSV file created at: SL23-001041_1_371_clinical_report/SL23-001041_1_371_mutsumm.csv
#
# file name:  SL23-001088_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001088_1_371.pdf
#
# CSV file created at: SL23-001088_1_371_clinical_report/SL23-001088_1_371_mutsumm.csv
#
# file name:  SL23-000536_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000536_1_370.pdf
#
# CSV file created at: SL23-000536_1_370_clinical_report/SL23-000536_1_370_mutsumm.csv
#
# file name:  SL23-000930_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000930_1_371.pdf
#
# CSV file created at: SL23-000930_1_371_clinical_report/SL23-000930_1_371_mutsumm.csv
#
# file name:  SL23-000876_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000876_1_371.pdf
#
# CSV file created at: SL23-000876_1_371_clinical_report/SL23-000876_1_371_mutsumm.csv
#
# file name:  SL23-000792_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000792_1_371.pdf
#
# CSV file created at: SL23-000792_1_371_clinical_report/SL23-000792_1_371_mutsumm.csv
#
# file name:  SL23-000337_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000337_1_370.pdf
#
# CSV file created at: SL23-000337_1_370_clinical_report/SL23-000337_1_370_mutsumm.csv
#
# file name:  SL24-000042_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000042_1_371.pdf
#
# CSV file created at: SL24-000042_1_371_clinical_report/SL24-000042_1_371_mutsumm.csv
#
# file name:  SL23-000700_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000700_1_371.pdf
#
# CSV file created at: SL23-000700_1_371_clinical_report/SL23-000700_1_371_mutsumm.csv
#
# file name:  SL23-000082_2_370  file_path:  Searchlight Info/SearchlightReports/SL23-000082_2_370.pdf
#
# CSV file created at: SL23-000082_2_370_clinical_report/SL23-000082_2_370_mutsumm.csv
#
# file name:  SL23-001060_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001060_1_371.pdf
#
# CSV file created at: SL23-001060_1_371_clinical_report/SL23-001060_1_371_mutsumm.csv
#
# file name:  SL23-000384_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000384_1_370.pdf
#
# CSV file created at: SL23-000384_1_370_clinical_report/SL23-000384_1_370_mutsumm.csv
#
# file name:  SL23-000451_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000451_1_370.pdf
#
# CSV file created at: SL23-000451_1_370_clinical_report/SL23-000451_1_370_mutsumm.csv
#
# file name:  SL23-000498_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000498_1_370.pdf
#
# CSV file created at: SL23-000498_1_370_clinical_report/SL23-000498_1_370_mutsumm.csv
#
# file name:  SL23-000517_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000517_1_370.pdf
#
# CSV file created at: SL23-000517_1_370_clinical_report/SL23-000517_1_370_mutsumm.csv
#
# file name:  SL23-000911_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000911_1_371.pdf
#
# CSV file created at: SL23-000911_1_371_clinical_report/SL23-000911_1_371_mutsumm.csv
#
# file name:  SL23-000857_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000857_1_371.pdf
#
# CSV file created at: SL23-000857_1_371_clinical_report/SL23-000857_1_371_mutsumm.csv
#
# file name:  SL23-000585_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000585_1_371.pdf
#
# CSV file created at: SL23-000585_1_371_clinical_report/SL23-000585_1_371_mutsumm.csv
#
# file name:  SL23-000558_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000558_1_371.pdf
#
# CSV file created at: SL23-000558_1_371_clinical_report/SL23-000558_1_371_mutsumm.csv
#
# file name:  SL23-000843_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000843_1_371.pdf
#
# CSV file created at: SL23-000843_1_371_clinical_report/SL23-000843_1_371_mutsumm.csv
#
# file name:  SL23-000905_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000905_1_371.pdf
#
# CSV file created at: SL23-000905_1_371_clinical_report/SL23-000905_1_371_mutsumm.csv
#
# file name:  SL23-000628_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000628_1_371.pdf
#
# CSV file created at: SL23-000628_1_371_clinical_report/SL23-000628_1_371_mutsumm.csv
#
# file name:  SL23-000445_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000445_1_370.pdf
#
# CSV file created at: SL23-000445_1_370_clinical_report/SL23-000445_1_370_mutsumm.csv
#
# file name:  SL23-000390_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000390_1_370.pdf
#
# CSV file created at: SL23-000390_1_370_clinical_report/SL23-000390_1_370_mutsumm.csv
#
# file name:  SL23-001074_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001074_1_371.pdf
#
# CSV file created at: SL23-001074_1_371_clinical_report/SL23-001074_1_371_mutsumm.csv
#
# file name:  SL23-000359_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000359_1_370.pdf
#
# CSV file created at: SL23-000359_1_370_clinical_report/SL23-000359_1_370_mutsumm.csv
#
# file name:  SL23-000652_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000652_1_371.pdf
#
# CSV file created at: SL23-000652_1_371_clinical_report/SL23-000652_1_371_mutsumm.csv
#
# file name:  SL23-000839_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000839_1_371.pdf
#
# CSV file created at: SL23-000839_1_371_clinical_report/SL23-000839_1_371_mutsumm.csv
#
# file name:  SL23-000714_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000714_1_371.pdf
#
# CSV file created at: SL23-000714_1_371_clinical_report/SL23-000714_1_371_mutsumm.csv
#
# file name:  SL24-000056_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000056_1_371.pdf
#
# CSV file created at: SL24-000056_1_371_clinical_report/SL24-000056_1_371_mutsumm.csv
#
# file name:  SL23-000115_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000115_1_370.pdf
#
# CSV file created at: SL23-000115_1_370_clinical_report/SL23-000115_1_370_mutsumm.csv
#
# file name:  SL23-000323_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000323_1_370.pdf
#
# CSV file created at: SL23-000323_1_370_clinical_report/SL23-000323_1_370_mutsumm.csv
#
# file name:  SL23-000053_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000053_1_370.pdf
#
# CSV file created at: SL23-000053_1_370_clinical_report/SL23-000053_1_370_mutsumm.csv
#
# file name:  SL24-000110_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000110_1_371.pdf
#
# CSV file created at: SL24-000110_1_371_clinical_report/SL24-000110_1_371_mutsumm.csv
#
# file name:  SL23-000469_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000469_1_370.pdf
#
# CSV file created at: SL23-000469_1_370_clinical_report/SL23-000469_1_370_mutsumm.csv
#
# file name:  SL23-000375_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000375_1_370.pdf
#
# CSV file created at: SL23-000375_1_370_clinical_report/SL23-000375_1_370_mutsumm.csv
#
# file name:  SL23-001091_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001091_1_371.pdf
#
# CSV file created at: SL23-001091_1_371_clinical_report/SL23-001091_1_371_mutsumm.csv
#
# file name:  SL24-000146_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000146_1_371.pdf
#
# CSV file created at: SL24-000146_1_371_clinical_report/SL24-000146_1_371_mutsumm.csv
#
# file name:  SL23-000042_1_369  file_path:  Searchlight Info/SearchlightReports/SL23-000042_1_369.pdf
#
# CSV file created at: SL23-000042_1_369_clinical_report/SL23-000042_1_369_mutsumm.csv
#
# file name:  SL23-000233_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000233_1_370.pdf
#
# CSV file created at: SL23-000233_1_370_clinical_report/SL23-000233_1_370_mutsumm.csv
#
# file name:  SL23-000929_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000929_1_371.pdf
#
# CSV file created at: SL23-000929_1_371_clinical_report/SL23-000929_1_371_mutsumm.csv
#
# file name:  SL23-000574_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000574_1_371.pdf
#
# CSV file created at: SL23-000574_1_371_clinical_report/SL23-000574_1_371_mutsumm.csv
#
# file name:  SL23-000280_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000280_1_370.pdf
#
# CSV file created at: SL23-000280_1_370_clinical_report/SL23-000280_1_370_mutsumm.csv
#
# file name:  SL23-000413_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000413_1_370.pdf
#
# CSV file created at: SL23-000413_1_370_clinical_report/SL23-000413_1_370_mutsumm.csv
#
# file name:  SL23-000139_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000139_1_370.pdf
#
# CSV file created at: SL23-000139_1_370_clinical_report/SL23-000139_1_370_mutsumm.csv
#
# file name:  SL23-001022_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001022_1_371.pdf
#
# CSV file created at: SL23-001022_1_371_clinical_report/SL23-001022_1_371_mutsumm.csv
#
# file name:  SL23-000815_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000815_1_371.pdf
#
# CSV file created at: SL23-000815_1_371_clinical_report/SL23-000815_1_371_mutsumm.csv
#
# file name:  SL23-000738_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000738_1_371.pdf
#
# CSV file created at: SL23-000738_1_371_clinical_report/SL23-000738_1_371_mutsumm.csv
#
# file name:  SL23-000953_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000953_1_371.pdf
#
# CSV file created at: SL23-000953_1_371_clinical_report/SL23-000953_1_371_mutsumm.csv
#
# file name:  SL23-000481_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000481_1_371.pdf
#
# CSV file created at: SL23-000481_1_371_clinical_report/SL23-000481_1_371_mutsumm.csv
#
# file name:  SL23-000947_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000947_1_371.pdf
#
# CSV file created at: SL23-000947_1_371_clinical_report/SL23-000947_1_371_mutsumm.csv
#
# file name:  SL23-001036_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001036_1_371.pdf
#
# CSV file created at: SL23-001036_1_371_clinical_report/SL23-001036_1_371_mutsumm.csv
#
# file name:  SL23-000407_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000407_1_370.pdf
#
# CSV file created at: SL23-000407_1_370_clinical_report/SL23-000407_1_370_mutsumm.csv
#
# file name:  SL23-000294_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000294_1_370.pdf
#
# CSV file created at: SL23-000294_1_370_clinical_report/SL23-000294_1_370_mutsumm.csv
#
# file name:  SL24-000128_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000128_1_371.pdf
#
# CSV file created at: SL24-000128_1_371_clinical_report/SL24-000128_1_371_mutsumm.csv
#
# file name:  SL23-000560_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000560_1_371.pdf
#
# CSV file created at: SL23-000560_1_371_clinical_report/SL23-000560_1_371_mutsumm.csv
#
# file name:  SL23-000610_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000610_1_371.pdf
#
# CSV file created at: SL23-000610_1_371_clinical_report/SL23-000610_1_371_mutsumm.csv
#
# file name:  SL23-000227_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000227_1_370.pdf
#
# CSV file created at: SL23-000227_1_370_clinical_report/SL23-000227_1_370_mutsumm.csv
#
# file name:  SL24-000152_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000152_1_371.pdf
#
# CSV file created at: SL24-000152_1_371_clinical_report/SL24-000152_1_371_mutsumm.csv
#
# file name:  SL23-000056_1_369  file_path:  Searchlight Info/SearchlightReports/SL23-000056_1_369.pdf
#
# CSV file created at: SL23-000056_1_369_clinical_report/SL23-000056_1_369_mutsumm.csv
#
# file name:  SL24-000222_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000222_1_371.pdf
#
# CSV file created at: SL24-000222_1_371_clinical_report/SL24-000222_1_371_mutsumm.csv
#
# file name:  SL23-001085_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001085_1_371.pdf
#
# CSV file created at: SL23-001085_1_371_clinical_report/SL23-001085_1_371_mutsumm.csv
#
# file name:  SL23-000157_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000157_1_370.pdf
#
# CSV file created at: SL23-000157_1_370_clinical_report/SL23-000157_1_370_mutsumm.csv
#
# file name:  SL24-000014_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000014_1_371.pdf
#
# CSV file created at: SL24-000014_1_371_clinical_report/SL24-000014_1_371_mutsumm.csv
#
# file name:  SL23-000682_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000682_1_371.pdf
#
# CSV file created at: SL23-000682_1_371_clinical_report/SL23-000682_1_371_mutsumm.csv
#
# file name:  SL23-000820_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000820_1_371.pdf
#
# CSV file created at: SL23-000820_1_371_clinical_report/SL23-000820_1_371_mutsumm.csv
#
# file name:  SL24-000086_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000086_1_371.pdf
#
# CSV file created at: SL24-000086_1_371_clinical_report/SL24-000086_1_371_mutsumm.csv
#
# file name:  SL23-000083_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000083_1_370.pdf
#
# CSV file created at: SL23-000083_1_370_clinical_report/SL23-000083_1_370_mutsumm.csv
#
# file name:  SL24-000109_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000109_1_371.pdf
#
# CSV file created at: SL24-000109_1_371_clinical_report/SL24-000109_1_371_mutsumm.csv
#
# file name:  SL23-000588_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000588_1_371.pdf
#
# CSV file created at: SL23-000588_1_371_clinical_report/SL23-000588_1_371_mutsumm.csv
#
# file name:  SL23-000893_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000893_1_371.pdf
#
# CSV file created at: SL23-000893_1_371_clinical_report/SL23-000893_1_371_mutsumm.csv
#
# file name:  SL23-000777_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000777_1_371.pdf
#
# CSV file created at: SL23-000777_1_371_clinical_report/SL23-000777_1_371_mutsumm.csv
#
# file name:  SL23-000631_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000631_1_371.pdf
#
# CSV file created at: SL23-000631_1_371_clinical_report/SL23-000631_1_371_mutsumm.csv
#
# file name:  SL24-000173_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000173_1_371.pdf
#
# CSV file created at: SL24-000173_1_371_clinical_report/SL24-000173_1_371_mutsumm.csv
#
# file name:  SL23-000206_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000206_1_370.pdf
#
# CSV file created at: SL23-000206_1_370_clinical_report/SL23-000206_1_370_mutsumm.csv
#
# file name:  SL23-000495_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000495_1_370.pdf
#
# CSV file created at: SL23-000495_1_370_clinical_report/SL23-000495_1_370_mutsumm.csv
#
# file name:  SL23-000340_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000340_1_370.pdf
#
# CSV file created at: SL23-000340_1_370_clinical_report/SL23-000340_1_370_mutsumm.csv
#
# file name:  SL23-000389_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000389_1_370.pdf
#
# CSV file created at: SL23-000389_1_370_clinical_report/SL23-000389_1_370_mutsumm.csv
#
# file name:  SL24-000203_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000203_1_371.pdf
#
# CSV file created at: SL24-000203_1_371_clinical_report/SL24-000203_1_371_mutsumm.csv
#
# file name:  SL23-001079_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001079_1_371.pdf
#
# CSV file created at: SL23-001079_1_371_clinical_report/SL23-001079_1_371_mutsumm.csv
#
# file name:  SL23-000354_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000354_1_370.pdf
#
# CSV file created at: SL23-000354_1_370_clinical_report/SL23-000354_1_370_mutsumm.csv
#
# file name:  SL24-000217_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000217_1_371.pdf
#
# CSV file created at: SL24-000217_1_371_clinical_report/SL24-000217_1_371_mutsumm.csv
#
# file name:  SL24-000021_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000021_1_371.pdf
#
# CSV file created at: SL24-000021_1_371_clinical_report/SL24-000021_1_371_mutsumm.csv
#
# file name:  SL23-000162_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000162_1_370.pdf
#
# CSV file created at: SL23-000162_1_370_clinical_report/SL23-000162_1_370_mutsumm.csv
#
# file name:  SL23-000212_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000212_1_370.pdf
#
# CSV file created at: SL23-000212_1_370_clinical_report/SL23-000212_1_370_mutsumm.csv
#
# file name:  SL24-000167_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000167_1_371.pdf
#
# CSV file created at: SL24-000167_1_371_clinical_report/SL24-000167_1_371_mutsumm.csv
#
# file name:  SL23-000625_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000625_1_371.pdf
#
# CSV file created at: SL23-000625_1_371_clinical_report/SL23-000625_1_371_mutsumm.csv
#
# file name:  SL23-000908_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000908_1_371.pdf
#
# CSV file created at: SL23-000908_1_371_clinical_report/SL23-000908_1_371_mutsumm.csv
#
# file name:  SL23-000763_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000763_1_371.pdf
#
# CSV file created at: SL23-000763_1_371_clinical_report/SL23-000763_1_371_mutsumm.csv
#
# file name:  SL23-000555_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000555_1_371.pdf
#
# CSV file created at: SL23-000555_1_371_clinical_report/SL23-000555_1_371_mutsumm.csv
#
# file name:  SL23-000097_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000097_1_370.pdf
#
# CSV file created at: SL23-000097_1_370_clinical_report/SL23-000097_1_370_mutsumm.csv
#
# file name:  SL23-001003_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001003_1_371.pdf
#
# CSV file created at: SL23-001003_1_371_clinical_report/SL23-001003_1_371_mutsumm.csv
#
# file name:  SL23-000432_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000432_1_370.pdf
#
# CSV file created at: SL23-000432_1_370_clinical_report/SL23-000432_1_370_mutsumm.csv
#
# file name:  SL23-000719_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000719_1_371.pdf
#
# CSV file created at: SL23-000719_1_371_clinical_report/SL23-000719_1_371_mutsumm.csv
#
# file name:  SL23-000696_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000696_1_371.pdf
#
# CSV file created at: SL23-000696_1_371_clinical_report/SL23-000696_1_371_mutsumm.csv
#
# file name:  SL23-000972_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000972_1_371.pdf
#
# CSV file created at: SL23-000972_1_371_clinical_report/SL23-000972_1_371_mutsumm.csv
#
# file name:  SL24-000178_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000178_1_371.pdf
#
# CSV file created at: SL24-000178_1_371_clinical_report/SL24-000178_1_371_mutsumm.csv
#
# file name:  SL23-000511_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000511_1_370.pdf
#
# CSV file created at: SL23-000511_1_370_clinical_report/SL23-000511_1_370_mutsumm.csv
#
# file name:  SL24-000208_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000208_1_371.pdf
#
# CSV file created at: SL24-000208_1_371_clinical_report/SL24-000208_1_371_mutsumm.csv
#
# file name:  SL23-000457_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000457_1_370.pdf
#
# CSV file created at: SL23-000457_1_370_clinical_report/SL23-000457_1_370_mutsumm.csv
#
# file name:  SL23-000898_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000898_1_371.pdf
#
# CSV file created at: SL23-000898_1_371_clinical_report/SL23-000898_1_371_mutsumm.csv
#
# file name:  SL23-000331_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000331_1_370.pdf
#
# CSV file created at: SL23-000331_1_370_clinical_report/SL23-000331_1_370_mutsumm.csv
#
# file name:  SL23-000107_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000107_1_370.pdf
#
# CSV file created at: SL23-000107_1_370_clinical_report/SL23-000107_1_370_mutsumm.csv
#
# file name:  SL24-000044_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000044_1_371.pdf
#
# CSV file created at: SL24-000044_1_371_clinical_report/SL24-000044_1_371_mutsumm.csv
#
# file name:  SL23-000277_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000277_1_370.pdf
#
# CSV file created at: SL23-000277_1_370_clinical_report/SL23-000277_1_370_mutsumm.csv
#
# file name:  SL24-000102_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000102_1_371.pdf
#
# CSV file created at: SL24-000102_1_371_clinical_report/SL24-000102_1_371_mutsumm.csv
#
# file name:  SL23-000088_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000088_1_370.pdf
#
# CSV file created at: SL23-000088_1_370_clinical_report/SL23-000088_1_370_mutsumm.csv
#
# file name:  SL23-000041_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000041_1_370.pdf
#
# CSV file created at: SL23-000041_1_370_clinical_report/SL23-000041_1_370_mutsumm.csv
#
# file name:  SL23-000640_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000640_1_371.pdf
#
# CSV file created at: SL23-000640_1_371_clinical_report/SL23-000640_1_371_mutsumm.csv
#
# file name:  SL23-000795.pdf  file_path:  Searchlight Info/SearchlightReports/SL23-000795.pdf.pdf
#
# CSV file created at: SL23-000795.pdf_clinical_report/SL23-000795.pdf_mutsumm.csv
#
# file name:  SL23-000979_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000979_1_371.pdf
#
# CSV file created at: SL23-000979_1_371_clinical_report/SL23-000979_1_371_mutsumm.csv
#
# file name:  SL23-000012_1_369  file_path:  Searchlight Info/SearchlightReports/SL23-000012_1_369.pdf
#
# CSV file created at: SL23-000012_1_369_clinical_report/SL23-000012_1_369_mutsumm.csv
#
# file name:  SL23-000263_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000263_1_370.pdf
#
# CSV file created at: SL23-000263_1_370_clinical_report/SL23-000263_1_370_mutsumm.csv
#
# file name:  SL23-000113_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000113_1_370.pdf
#
# CSV file created at: SL23-000113_1_370_clinical_report/SL23-000113_1_370_mutsumm.csv
#
# file name:  SL24-000050_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000050_1_371.pdf
#
# CSV file created at: SL24-000050_1_371_clinical_report/SL24-000050_1_371_mutsumm.csv
#
# file name:  SL24-000099_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000099_1_371.pdf
#
# CSV file created at: SL24-000099_1_371_clinical_report/SL24-000099_1_371_mutsumm.csv
#
# file name:  SL23-001008_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001008_1_371.pdf
#
# CSV file created at: SL23-001008_1_371_clinical_report/SL23-001008_1_371_mutsumm.csv
#
# file name:  SL23-000903_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000903_1_371.pdf
#
# CSV file created at: SL23-000903_1_371_clinical_report/SL23-000903_1_371_mutsumm.csv
#
# file name:  SL23-000845_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000845_1_371.pdf
#
# CSV file created at: SL23-000845_1_371_clinical_report/SL23-000845_1_371_mutsumm.csv
#
# file name:  SL23-000768_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000768_1_371.pdf
#
# CSV file created at: SL23-000768_1_371_clinical_report/SL23-000768_1_371_mutsumm.csv
#
# file name:  SL23-000443_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000443_1_370.pdf
#
# CSV file created at: SL23-000443_1_370_clinical_report/SL23-000443_1_370_mutsumm.csv
#
# file name:  SL23-000169_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000169_1_370.pdf
#
# CSV file created at: SL23-000169_1_370_clinical_report/SL23-000169_1_370_mutsumm.csv
#
# file name:  SL23-000396_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000396_1_370.pdf
#
# CSV file created at: SL23-000396_1_370_clinical_report/SL23-000396_1_370_mutsumm.csv
#
# file name:  SL23-001072_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001072_1_371.pdf
#
# CSV file created at: SL23-001072_1_371_clinical_report/SL23-001072_1_371_mutsumm.csv
#
# file name:  SL23-000068_1_369  file_path:  Searchlight Info/SearchlightReports/SL23-000068_1_369.pdf
#
# CSV file created at: SL23-000068_1_369_clinical_report/SL23-000068_1_369_mutsumm.csv
#
# file name:  SL23-000733_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000733_1_371.pdf
#
# CSV file created at: SL23-000733_1_371_clinical_report/SL23-000733_1_371_mutsumm.csv
#
# file name:  SL23-000675_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000675_1_371.pdf
#
# CSV file created at: SL23-000675_1_371_clinical_report/SL23-000675_1_371_mutsumm.csv
#
# file name:  SL23-000991_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000991_1_371.pdf
#
# CSV file created at: SL23-000991_1_371_clinical_report/SL23-000991_1_371_mutsumm.csv
#
# file name:  SL23-000958_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000958_1_371.pdf
#
# CSV file created at: SL23-000958_1_371_clinical_report/SL23-000958_1_371_mutsumm.csv
#
# file name:  SL23-000242_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000242_1_370.pdf
#
# CSV file created at: SL23-000242_1_370_clinical_report/SL23-000242_1_370_mutsumm.csv
#
# file name:  SL23-000074_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000074_1_370.pdf
#
# CSV file created at: SL23-000074_1_370_clinical_report/SL23-000074_1_370_mutsumm.csv
#
# file name:  SL24-000137_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000137_1_371.pdf
#
# CSV file created at: SL24-000137_1_371_clinical_report/SL24-000137_1_371_mutsumm.csv
#
# file name:  SL23-001029_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001029_1_371.pdf
#
# CSV file created at: SL23-001029_1_371_clinical_report/SL23-001029_1_371_mutsumm.csv
#
# file name:  SL24-000188_2_371  file_path:  Searchlight Info/SearchlightReports/SL24-000188_2_371.pdf
#
# CSV file created at: SL24-000188_2_371_clinical_report/SL24-000188_2_371_mutsumm.csv
#
# file name:  SL24-000071_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000071_1_371.pdf
#
# CSV file created at: SL24-000071_1_371_clinical_report/SL24-000071_1_371_mutsumm.csv
#
# file name:  SL23-000418_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000418_1_370.pdf
#
# CSV file created at: SL23-000418_1_370_clinical_report/SL23-000418_1_370_mutsumm.csv
#
# file name:  SL23-000922_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000922_1_371.pdf
#
# CSV file created at: SL23-000922_1_371_clinical_report/SL23-000922_1_371_mutsumm.csv
#
# file name:  SL23-000749_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000749_1_371.pdf
#
# CSV file created at: SL23-000749_1_371_clinical_report/SL23-000749_1_371_mutsumm.csv
#
# file name:  SL23-000864_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000864_1_371.pdf
#
# CSV file created at: SL23-000864_1_371_clinical_report/SL23-000864_1_371_mutsumm.csv
#
# file name:  SL23-001053_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001053_1_371.pdf
#
# CSV file created at: SL23-001053_1_371_clinical_report/SL23-001053_1_371_mutsumm.csv
#
# file name:  SL23-000181_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000181_1_370.pdf
#
# CSV file created at: SL23-000181_1_370_clinical_report/SL23-000181_1_370_mutsumm.csv
#
# file name:  SL23-000238_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000238_1_370.pdf
#
# CSV file created at: SL23-000238_1_370_clinical_report/SL23-000238_1_370_mutsumm.csv
#
# file name:  SL24-000184_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000184_1_371.pdf
#
# CSV file created at: SL24-000184_1_371_clinical_report/SL24-000184_1_371_mutsumm.csv
#
# file name:  SL24-000190_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000190_1_371.pdf
#
# CSV file created at: SL24-000190_1_371_clinical_report/SL24-000190_1_371_mutsumm.csv
#
# file name:  SL24-000159_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000159_1_371.pdf
#
# CSV file created at: SL24-000159_1_371_clinical_report/SL24-000159_1_371_mutsumm.csv
#
# file name:  SL23-000476_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000476_1_370.pdf
#
# CSV file created at: SL23-000476_1_370_clinical_report/SL23-000476_1_370_mutsumm.csv
#
# file name:  SL23-000195_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000195_1_370.pdf
#
# CSV file created at: SL23-000195_1_370_clinical_report/SL23-000195_1_370_mutsumm.csv
#
# file name:  SL23-001047_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001047_1_371.pdf
#
# CSV file created at: SL23-001047_1_371_clinical_report/SL23-001047_1_371_mutsumm.csv
#
# file name:  SL24-000229_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000229_1_371.pdf
#
# CSV file created at: SL24-000229_1_371_clinical_report/SL24-000229_1_371_mutsumm.csv
#
# file name:  SL23-000870_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000870_1_371.pdf
#
# CSV file created at: SL23-000870_1_371_clinical_report/SL23-000870_1_371_mutsumm.csv
#
# file name:  SL23-000794_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000794_1_371.pdf
#
# CSV file created at: SL23-000794_1_371_clinical_report/SL23-000794_1_371_mutsumm.csv
#
# file name:  SL23-000936_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000936_1_371.pdf
#
# CSV file created at: SL23-000936_1_371_clinical_report/SL23-000936_1_371_mutsumm.csv
#
# file name:  SL24-000065_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000065_1_371.pdf
#
# CSV file created at: SL24-000065_1_371_clinical_report/SL24-000065_1_371_mutsumm.csv
#
# file name:  SL23-000126_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000126_1_370.pdf
#
# CSV file created at: SL23-000126_1_370_clinical_report/SL23-000126_1_370_mutsumm.csv
#
# file name:  SL23-000310_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000310_1_370.pdf
#
# CSV file created at: SL23-000310_1_370_clinical_report/SL23-000310_1_370_mutsumm.csv
#
# file name:  SL24-000253_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000253_1_371.pdf
#
# CSV file created at: SL24-000253_1_371_clinical_report/SL24-000253_1_371_mutsumm.csv
#
# file name:  SL24-000123_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000123_1_371.pdf
#
# CSV file created at: SL24-000123_1_371_clinical_report/SL24-000123_1_371_mutsumm.csv
#
# file name:  SL23-000256_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000256_1_370.pdf
#
# CSV file created at: SL23-000256_1_370_clinical_report/SL23-000256_1_370_mutsumm.csv
#
# file name:  SL23-000199_2_370  file_path:  Searchlight Info/SearchlightReports/SL23-000199_2_370.pdf
#
# CSV file created at: SL23-000199_2_370_clinical_report/SL23-000199_2_370_mutsumm.csv
#
# file name:  SL23-000985_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000985_1_371.pdf
#
# CSV file created at: SL23-000985_1_371_clinical_report/SL23-000985_1_371_mutsumm.csv
#
# file name:  SL23-000661_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000661_1_371.pdf
#
# CSV file created at: SL23-000661_1_371_clinical_report/SL23-000661_1_371_mutsumm.csv
#
# file name:  SL23-000727_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000727_1_371.pdf
#
# CSV file created at: SL23-000727_1_371_clinical_report/SL23-000727_1_371_mutsumm.csv
#
# file name:  SL23-000637_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000637_1_371.pdf
#
# CSV file created at: SL23-000637_1_371_clinical_report/SL23-000637_1_371_mutsumm.csv
#
# file name:  SL23-000895_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000895_1_371.pdf
#
# CSV file created at: SL23-000895_1_371_clinical_report/SL23-000895_1_371_mutsumm.csv
#
# file name:  SL23-000008_1.pdf  file_path:  Searchlight Info/SearchlightReports/SL23-000008_1.pdf.pdf
#
# CSV file created at: SL23-000008_1.pdf_clinical_report/SL23-000008_1.pdf_mutsumm.csv
#
# file name:  SL23-000771_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000771_1_371.pdf
#
# CSV file created at: SL23-000771_1_371_clinical_report/SL23-000771_1_371_mutsumm.csv
#
# file name:  SL23-000493_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000493_1_370.pdf
#
# CSV file created at: SL23-000493_1_370_clinical_report/SL23-000493_1_370_mutsumm.csv
#
# file name:  SL24-000033_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000033_1_371.pdf
#
# CSV file created at: SL24-000033_1_371_clinical_report/SL24-000033_1_371_mutsumm.csv
#
# file name:  SL23-000346_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000346_1_370.pdf
#
# CSV file created at: SL23-000346_1_370_clinical_report/SL23-000346_1_370_mutsumm.csv
#
# file name:  SL24-000175_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000175_1_371.pdf
#
# CSV file created at: SL24-000175_1_371_clinical_report/SL24-000175_1_371_mutsumm.csv
#
# file name:  SL23-000826_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000826_1_371.pdf
#
# CSV file created at: SL23-000826_1_371_clinical_report/SL23-000826_1_371_mutsumm.csv
#
# file name:  SL23-000960_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000960_1_371.pdf
#
# CSV file created at: SL23-000960_1_371_clinical_report/SL23-000960_1_371_mutsumm.csv
#
# file name:  SL23-000684_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000684_1_371.pdf
#
# CSV file created at: SL23-000684_1_371_clinical_report/SL23-000684_1_371_mutsumm.csv
#
# file name:  SL23-000420_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000420_1_370.pdf
#
# CSV file created at: SL23-000420_1_370_clinical_report/SL23-000420_1_370_mutsumm.csv
#
# file name:  SL24-000049_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000049_1_371.pdf
#
# CSV file created at: SL24-000049_1_371_clinical_report/SL24-000049_1_371_mutsumm.csv
#
# file name:  SL23-001011_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001011_1_371.pdf
#
# CSV file created at: SL23-001011_1_371_clinical_report/SL23-001011_1_371_mutsumm.csv
#
# file name:  SL23-000328_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000328_1_370.pdf
#
# CSV file created at: SL23-000328_1_370_clinical_report/SL23-000328_1_370_mutsumm.csv
#
# file name:  SL23-001005_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001005_1_371.pdf
#
# CSV file created at: SL23-001005_1_371_clinical_report/SL23-001005_1_371_mutsumm.csv
#
# file name:  SL24-000094_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000094_1_371.pdf
#
# CSV file created at: SL24-000094_1_371_clinical_report/SL24-000094_1_371_mutsumm.csv
#
# file name:  SL23-000218_2_370  file_path:  Searchlight Info/SearchlightReports/SL23-000218_2_370.pdf
#
# CSV file created at: SL23-000218_2_370_clinical_report/SL23-000218_2_370_mutsumm.csv
#
# file name:  SL23-000091_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000091_1_370.pdf
#
# CSV file created at: SL23-000091_1_370_clinical_report/SL23-000091_1_370_mutsumm.csv
#
# file name:  SL23-000690_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000690_1_371.pdf
#
# CSV file created at: SL23-000690_1_371_clinical_report/SL23-000690_1_371_mutsumm.csv
#
# file name:  SL23-000974_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000974_1_371.pdf
#
# CSV file created at: SL23-000974_1_371_clinical_report/SL23-000974_1_371_mutsumm.csv
#
# file name:  SL23-000854  file_path:  Searchlight Info/SearchlightReports/SL23-000854.pdf
#
# CSV file created at: SL23-000854_clinical_report/SL23-000854_mutsumm.csv
#
# file name:  SL23-000832_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000832_1_371.pdf
#
# CSV file created at: SL23-000832_1_371_clinical_report/SL23-000832_1_371_mutsumm.csv
#
# file name:  SL23-000214_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000214_1_370.pdf
#
# CSV file created at: SL23-000214_1_370_clinical_report/SL23-000214_1_370_mutsumm.csv
#
# file name:  SL24-000161_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000161_1_371.pdf
#
# CSV file created at: SL24-000161_1_371_clinical_report/SL24-000161_1_371_mutsumm.csv
#
# file name:  SL24-000211_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000211_1_371.pdf
#
# CSV file created at: SL24-000211_1_371_clinical_report/SL24-000211_1_371_mutsumm.csv
#
# file name:  SL23-000352_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000352_1_370.pdf
#
# CSV file created at: SL23-000352_1_370_clinical_report/SL23-000352_1_370_mutsumm.csv
#
# file name:  SL23-000164_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000164_1_370.pdf
#
# CSV file created at: SL23-000164_1_370_clinical_report/SL23-000164_1_370_mutsumm.csv
#
# file name:  SL23-000487_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000487_1_370.pdf
#
# CSV file created at: SL23-000487_1_370_clinical_report/SL23-000487_1_370_mutsumm.csv
#
# file name:  SL24-000027_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000027_1_371.pdf
#
# CSV file created at: SL24-000027_1_371_clinical_report/SL24-000027_1_371_mutsumm.csv
#
# file name:  SL23-000765_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000765_1_371.pdf
#
# CSV file created at: SL23-000765_1_371_clinical_report/SL23-000765_1_371_mutsumm.csv
#
# file name:  SL23-000553_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000553_1_371.pdf
#
# CSV file created at: SL23-000553_1_371_clinical_report/SL23-000553_1_371_mutsumm.csv
#
# file name:  SL23-000881_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000881_1_371.pdf
#
# CSV file created at: SL23-000881_1_371_clinical_report/SL23-000881_1_371_mutsumm.csv
#
# file name:  SL23-000848_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000848_1_371.pdf
#
# CSV file created at: SL23-000848_1_371_clinical_report/SL23-000848_1_371_mutsumm.csv
#
# file name:  SL23-000623_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000623_1_371.pdf
#
# CSV file created at: SL23-000623_1_371_clinical_report/SL23-000623_1_371_mutsumm.csv
#
# file name:  SL23-000415_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000415_1_370.pdf
#
# CSV file created at: SL23-000415_1_370_clinical_report/SL23-000415_1_370_mutsumm.csv
#
# file name:  SL23-001024_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001024_1_371.pdf
#
# CSV file created at: SL23-001024_1_371_clinical_report/SL23-001024_1_371_mutsumm.csv
#
# file name:  SL23-000309_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000309_1_370.pdf
#
# CSV file created at: SL23-000309_1_370_clinical_report/SL23-000309_1_370_mutsumm.csv
#
# file name:  SL23-000079_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000079_1_370.pdf
#
# CSV file created at: SL23-000079_1_370_clinical_report/SL23-000079_1_370_mutsumm.csv
#
# file name:  SL23-000286_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000286_1_370.pdf
#
# CSV file created at: SL23-000286_1_370_clinical_report/SL23-000286_1_370_mutsumm.csv
#
# file name:  SL23-000955_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000955_1_371.pdf
#
# CSV file created at: SL23-000955_1_371_clinical_report/SL23-000955_1_371_mutsumm.csv
#
# file name:  SL23-000678_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000678_1_371.pdf
#
# CSV file created at: SL23-000678_1_371_clinical_report/SL23-000678_1_371_mutsumm.csv
#
# file name:  SL23-000813_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000813_1_371.pdf
#
# CSV file created at: SL23-000813_1_371_clinical_report/SL23-000813_1_371_mutsumm.csv
#
# file name:  SL23-000508_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000508_1_371.pdf
#
# CSV file created at: SL23-000508_1_371_clinical_report/SL23-000508_1_371_mutsumm.csv
#
# file name:  SL24-000140_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000140_1_371.pdf
#
# CSV file created at: SL24-000140_1_371_clinical_report/SL24-000140_1_371_mutsumm.csv
#
# file name:  SL23-000235_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000235_1_370.pdf
#
# CSV file created at: SL23-000235_1_370_clinical_report/SL23-000235_1_370_mutsumm.csv
#
# file name:  SL24-000070_2_371  file_path:  Searchlight Info/SearchlightReports/SL24-000070_2_371.pdf
#
# CSV file created at: SL24-000070_2_371_clinical_report/SL24-000070_2_371_mutsumm.csv
#
# file name:  SL24-000006_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000006_1_371.pdf
#
# CSV file created at: SL24-000006_1_371_clinical_report/SL24-000006_1_371_mutsumm.csv
#
# file name:  SL23-000145_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000145_1_370.pdf
#
# CSV file created at: SL23-000145_1_370_clinical_report/SL23-000145_1_370_mutsumm.csv
#
# file name:  SL23-000373_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000373_1_370.pdf
#
# CSV file created at: SL23-000373_1_370_clinical_report/SL23-000373_1_370_mutsumm.csv
#
# file name:  SL24-000230_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000230_1_371.pdf
#
# CSV file created at: SL24-000230_1_371_clinical_report/SL24-000230_1_371_mutsumm.csv
#
# file name:  SL23-000869_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000869_1_371.pdf
#
# CSV file created at: SL23-000869_1_371_clinical_report/SL23-000869_1_371_mutsumm.csv
#
# file name:  SL23-000572_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000572_1_371.pdf
#
# CSV file created at: SL23-000572_1_371_clinical_report/SL23-000572_1_371_mutsumm.csv
#
# file name:  SL23-000434_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000434_1_371.pdf
#
# CSV file created at: SL23-000434_1_371_clinical_report/SL23-000434_1_371_mutsumm.csv
#
# file name:  SL23-000616_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000616_1_371.pdf
#
# CSV file created at: SL23-000616_1_371_clinical_report/SL23-000616_1_371_mutsumm.csv
#
# file name:  SL23-000750_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000750_1_371.pdf
#
# CSV file created at: SL23-000750_1_371_clinical_report/SL23-000750_1_371_mutsumm.csv
#
# file name:  SL23-000566_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000566_1_371.pdf
#
# CSV file created at: SL23-000566_1_371_clinical_report/SL23-000566_1_371_mutsumm.csv
#
# file name:  SL23-000367_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000367_1_370.pdf
#
# CSV file created at: SL23-000367_1_370_clinical_report/SL23-000367_1_370_mutsumm.csv
#
# file name:  SL24-000012_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000012_1_371.pdf
#
# CSV file created at: SL24-000012_1_371_clinical_report/SL24-000012_1_371_mutsumm.csv
#
# file name:  SL23-000198_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000198_1_370.pdf
#
# CSV file created at: SL23-000198_1_370_clinical_report/SL23-000198_1_370_mutsumm.csv
#
# file name:  SL23-000221_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000221_1_370.pdf
#
# CSV file created at: SL23-000221_1_370_clinical_report/SL23-000221_1_370_mutsumm.csv
#
# file name:  SL24-000154_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000154_1_371.pdf
#
# CSV file created at: SL24-000154_1_371_clinical_report/SL24-000154_1_371_mutsumm.csv
#
# file name:  SL23-000941_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000941_1_371.pdf
#
# CSV file created at: SL23-000941_1_371_clinical_report/SL23-000941_1_371_mutsumm.csv
#
# file name:  SL23-000292_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000292_1_370.pdf
#
# ...
#
# file name:  SL23-000395_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000395_1_370.pdf
#
# CSV file created at: SL23-000395_1_370_clinical_report/SL23-000395_1_370_mutsumm.csv
#
# file name:  SL23-000594_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000594_1_371.pdf
#
# CSV file created at: SL23-000594_1_371_clinical_report/SL23-000594_1_371_mutsumm.csv
#
# file name:  SL23-000900_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000900_1_371.pdf
#
# CSV file created at: SL23-000900_1_371_clinical_report/SL23-000900_1_371_mutsumm.csv
#
# file name:  SL23-000639_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000639_1_371.pdf
#
# CSV file created at: SL23-000639_1_371_clinical_report/SL23-000639_1_371_mutsumm.csv
#
# file name:  SL23-000914_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000914_1_371.pdf
#
# CSV file created at: SL23-000914_1_371_clinical_report/SL23-000914_1_371_mutsumm.csv
#
# file name:  SL23-000852_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000852_1_371.pdf
#
# CSV file created at: SL23-000852_1_371_clinical_report/SL23-000852_1_371_mutsumm.csv
#
# file name:  SL23-000549_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000549_1_371.pdf
#
# CSV file created at: SL23-000549_1_371_clinical_report/SL23-000549_1_371_mutsumm.csv
#
# file name:  SL23-000580_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000580_1_371.pdf
#
# CSV file created at: SL23-000580_1_371_clinical_report/SL23-000580_1_371_mutsumm.csv
#
# file name:  SL23-001065_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001065_1_371.pdf
#
# CSV file created at: SL23-001065_1_371_clinical_report/SL23-001065_1_371_mutsumm.csv
#
# file name:  SL23-000348_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000348_1_370.pdf
#
# CSV file created at: SL23-000348_1_370_clinical_report/SL23-000348_1_370_mutsumm.csv
#
# file name:  SL23-000038_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000038_1_370.pdf
#
# CSV file created at: SL23-000038_1_370_clinical_report/SL23-000038_1_370_mutsumm.csv
#
# file name:  SL23-000705_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000705_1_371.pdf
#
# CSV file created at: SL23-000705_1_371_clinical_report/SL23-000705_1_371_mutsumm.csv
#
# file name:  SL23-000533_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000533_1_371.pdf
#
# CSV file created at: SL23-000533_1_371_clinical_report/SL23-000533_1_371_mutsumm.csv
#
# file name:  SL23-000643_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000643_1_371.pdf
#
# CSV file created at: SL23-000643_1_371_clinical_report/SL23-000643_1_371_mutsumm.csv
#
# file name:  SL23-000332_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000332_1_370.pdf
#
# CSV file created at: SL23-000332_1_370_clinical_report/SL23-000332_1_370_mutsumm.csv
#
# file name:  SL24-000047_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000047_1_371.pdf
#
# CSV file created at: SL24-000047_1_371_clinical_report/SL24-000047_1_371_mutsumm.csv
#
# file name:  SL23-000104_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000104_1_370.pdf
#
# CSV file created at: SL23-000104_1_370_clinical_report/SL23-000104_1_370_mutsumm.csv
#
# file name:  SL23-000222_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000222_1_370.pdf
#
# CSV file created at: SL23-000222_1_370_clinical_report/SL23-000222_1_370_mutsumm.csv
#
# file name:  SL24-000227_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000227_1_371.pdf
#
# CSV file created at: SL24-000227_1_371_clinical_report/SL24-000227_1_371_mutsumm.csv
#
# file name:  SL23-001080_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001080_1_371.pdf
#
# CSV file created at: SL23-001080_1_371_clinical_report/SL23-001080_1_371_mutsumm.csv
#
# file name:  SL23-000364_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000364_1_370.pdf
#
# CSV file created at: SL23-000364_1_370_clinical_report/SL23-000364_1_370_mutsumm.csv
#
# file name:  SL23-001049_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001049_1_371.pdf
#
# CSV file created at: SL23-001049_1_371_clinical_report/SL23-001049_1_371_mutsumm.csv
#
# file name:  SL23-000478_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000478_1_370.pdf
#
# CSV file created at: SL23-000478_1_370_clinical_report/SL23-000478_1_370_mutsumm.csv
#
# file name:  SL24-000011_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000011_1_371.pdf
#
# CSV file created at: SL24-000011_1_371_clinical_report/SL24-000011_1_371_mutsumm.csv
#
# file name:  SL23-000753_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000753_1_371.pdf
#
# CSV file created at: SL23-000753_1_371_clinical_report/SL23-000753_1_371_mutsumm.csv
#
# file name:  SL23-000565_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000565_1_371.pdf
#
# CSV file created at: SL23-000565_1_371_clinical_report/SL23-000565_1_371_mutsumm.csv
#
# file name:  SL23-000615_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000615_1_371.pdf
#
# CSV file created at: SL23-000615_1_371_clinical_report/SL23-000615_1_371_mutsumm.csv
#
# file name:  SL23-001033_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001033_1_371.pdf
#
# CSV file created at: SL23-001033_1_371_clinical_report/SL23-001033_1_371_mutsumm.csv
#
# file name:  SL23-000402_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000402_1_370.pdf
#
# CSV file created at: SL23-000402_1_370_clinical_report/SL23-000402_1_370_mutsumm.csv
#
# file name:  SL23-000128_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000128_1_370.pdf
#
# CSV file created at: SL23-000128_1_370_clinical_report/SL23-000128_1_370_mutsumm.csv
#
# file name:  SL23-000291_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000291_1_370.pdf
#
# CSV file created at: SL23-000291_1_370_clinical_report/SL23-000291_1_370_mutsumm.csv
#
# file name:  SL23-000942_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000942_1_371.pdf
#
# CSV file created at: SL23-000942_1_371_clinical_report/SL23-000942_1_371_mutsumm.csv
#
# file name:  SL23-000729_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000729_1_371.pdf
#
# CSV file created at: SL23-000729_1_371_clinical_report/SL23-000729_1_371_mutsumm.csv
#
# file name:  SL23-000810_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000810_1_371.pdf
#
# CSV file created at: SL23-000810_1_371_clinical_report/SL23-000810_1_371_mutsumm.csv
#
# file name:  SL23-000956_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000956_1_371.pdf
#
# CSV file created at: SL23-000956_1_371_clinical_report/SL23-000956_1_371_mutsumm.csv
#
# file name:  SL24-000139_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000139_1_371.pdf
#
# CSV file created at: SL24-000139_1_371_clinical_report/SL24-000139_1_371_mutsumm.csv
#
# file name:  SL23-000285_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000285_1_370.pdf
#
# CSV file created at: SL23-000285_1_370_clinical_report/SL23-000285_1_370_mutsumm.csv
#
# file name:  SL23-000416_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000416_1_370.pdf
#
# CSV file created at: SL23-000416_1_370_clinical_report/SL23-000416_1_370_mutsumm.csv
#
# file name:  SL24-000249_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000249_1_371.pdf
#
# CSV file created at: SL24-000249_1_371_clinical_report/SL24-000249_1_371_mutsumm.csv
#
# file name:  SL23-001027_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001027_1_371.pdf
#
# CSV file created at: SL23-001027_1_371_clinical_report/SL23-001027_1_371_mutsumm.csv
#
# file name:  SL23-000571_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000571_1_371.pdf
#
# CSV file created at: SL23-000571_1_371_clinical_report/SL23-000571_1_371_mutsumm.csv
#
# file name:  SL23-000747_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000747_1_371.pdf
#
# CSV file created at: SL23-000747_1_371_clinical_report/SL23-000747_1_371_mutsumm.csv
#
# file name:  SL23-000146_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000146_1_370.pdf
#
# CSV file created at: SL23-000146_1_370_clinical_report/SL23-000146_1_370_mutsumm.csv
#
# file name:  SL24-000005_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000005_1_371.pdf
#
# CSV file created at: SL24-000005_1_371_clinical_report/SL24-000005_1_371_mutsumm.csv
#
# file name:  SL23-000370_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000370_1_370.pdf
#
# CSV file created at: SL23-000370_1_370_clinical_report/SL23-000370_1_370_mutsumm.csv
#
# file name:  SL23-001094_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001094_1_371.pdf
#
# CSV file created at: SL23-001094_1_371_clinical_report/SL23-001094_1_371_mutsumm.csv
#
# file name:  SL24-000143_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000143_1_371.pdf
#
# CSV file created at: SL24-000143_1_371_clinical_report/SL24-000143_1_371_mutsumm.csv
#
# file name:  SL23-000236_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000236_1_370.pdf
#
# CSV file created at: SL23-000236_1_370_clinical_report/SL23-000236_1_370_mutsumm.csv
#
# file name:  SL23-000831_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000831_1_371.pdf
#
# CSV file created at: SL23-000831_1_371_clinical_report/SL23-000831_1_371_mutsumm.csv
#
# file name:  SL23-000693_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000693_1_371.pdf
#
# CSV file created at: SL23-000693_1_371_clinical_report/SL23-000693_1_371_mutsumm.csv
#
# file name:  SL23-000977_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000977_1_371.pdf
#
# CSV file created at: SL23-000977_1_371_clinical_report/SL23-000977_1_371_mutsumm.csv
#
# file name:  SL23-000092_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000092_1_370.pdf
#
# CSV file created at: SL23-000092_1_370_clinical_report/SL23-000092_1_370_mutsumm.csv
#
# file name:  SL24-000118_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000118_1_371.pdf
#
# CSV file created at: SL24-000118_1_371_clinical_report/SL24-000118_1_371_mutsumm.csv
#
# file name:  SL23-001006_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001006_1_371.pdf
#
# CSV file created at: SL23-001006_1_371_clinical_report/SL23-001006_1_371_mutsumm.csv
#
# file name:  SL24-000097_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000097_1_371.pdf
#
# CSV file created at: SL24-000097_1_371_clinical_report/SL24-000097_1_371_mutsumm.csv
#
# file name:  SL23-000437_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000437_1_370.pdf
#
# CSV file created at: SL23-000437_1_370_clinical_report/SL23-000437_1_370_mutsumm.csv
#
# file name:  SL23-000620_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000620_1_371.pdf
#
# CSV file created at: SL23-000620_1_371_clinical_report/SL23-000620_1_371_mutsumm.csv
#
# file name:  SL23-000766_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000766_1_371.pdf
#
# CSV file created at: SL23-000766_1_371_clinical_report/SL23-000766_1_371_mutsumm.csv
#
# file name:  SL23-000882_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000882_1_371.pdf
#
# CSV file created at: SL23-000882_1_371_clinical_report/SL23-000882_1_371_mutsumm.csv
#
# file name:  SL23-000599_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000599_1_371.pdf
#
# CSV file created at: SL23-000599_1_371_clinical_report/SL23-000599_1_371_mutsumm.csv
#
# file name:  SL23-000351_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000351_1_370.pdf
#
# CSV file created at: SL23-000351_1_370_clinical_report/SL23-000351_1_370_mutsumm.csv
#
# file name:  SL23-000398_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000398_1_370.pdf
#
# CSV file created at: SL23-000398_1_370_clinical_report/SL23-000398_1_370_mutsumm.csv
#
# file name:  SL24-000024_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000024_1_371.pdf
#
# CSV file created at: SL24-000024_1_371_clinical_report/SL24-000024_1_371_mutsumm.csv
#
# file name:  SL23-000167_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000167_1_370.pdf
#
# CSV file created at: SL23-000167_1_370_clinical_report/SL23-000167_1_370_mutsumm.csv
#
# file name:  SL23-000217_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000217_1_370.pdf
#
# CSV file created at: SL23-000217_1_370_clinical_report/SL23-000217_1_370_mutsumm.csv
#
# file name:  SL24-000162_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000162_1_371.pdf
#
# CSV file created at: SL24-000162_1_371_clinical_report/SL24-000162_1_371_mutsumm.csv
#
# file name:  SL24-000176_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000176_1_371.pdf
#
# CSV file created at: SL24-000176_1_371_clinical_report/SL24-000176_1_371_mutsumm.csv
#
# file name:  SL24-000030_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000030_1_371.pdf
#
# CSV file created at: SL24-000030_1_371_clinical_report/SL24-000030_1_371_mutsumm.csv
#
# file name:  SL23-000490_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000490_1_370.pdf
#
# CSV file created at: SL23-000490_1_370_clinical_report/SL23-000490_1_370_mutsumm.csv
#
# file name:  SL23-000173_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000173_1_370.pdf
#
# CSV file created at: SL23-000173_1_370_clinical_report/SL23-000173_1_370_mutsumm.csv
#
# file name:  SL23-000459_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000459_1_370.pdf
#
# CSV file created at: SL23-000459_1_370_clinical_report/SL23-000459_1_370_mutsumm.csv
#
# file name:  SL23-001068_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001068_1_371.pdf
#
# CSV file created at: SL23-001068_1_371_clinical_report/SL23-001068_1_371_mutsumm.csv
#
# file name:  SL23-000345_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000345_1_370.pdf
#
# CSV file created at: SL23-000345_1_370_clinical_report/SL23-000345_1_370_mutsumm.csv
#
# file name:  SL24-000206_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000206_1_371.pdf
#
# CSV file created at: SL24-000206_1_371_clinical_report/SL24-000206_1_371_mutsumm.csv
#
# file name:  SL23-000544_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000544_1_371.pdf
#
# CSV file created at: SL23-000544_1_371_clinical_report/SL23-000544_1_371_mutsumm.csv
#
# file name:  SL23-000896_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000896_1_371.pdf
#
# CSV file created at: SL23-000896_1_371_clinical_report/SL23-000896_1_371_mutsumm.csv
#
# file name:  SL23-000919_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000919_1_371.pdf
#
# CSV file created at: SL23-000919_1_371_clinical_report/SL23-000919_1_371_mutsumm.csv
#
# file name:  SL23-000634_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000634_1_371.pdf
#
# CSV file created at: SL23-000634_1_371_clinical_report/SL23-000634_1_371_mutsumm.csv
#
# file name:  SL24-000083_1_371  file_path:  Searchlight Info/SearchlightReports/SL24-000083_1_371.pdf
#
# CSV file created at: SL24-000083_1_371_clinical_report/SL24-000083_1_371_mutsumm.csv
#
# file name:  SL23-000423_1_370  file_path:  Searchlight Info/SearchlightReports/SL23-000423_1_370.pdf
#
# CSV file created at: SL23-000423_1_370_clinical_report/SL23-000423_1_370_mutsumm.csv
#
# file name:  SL23-001012_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-001012_1_371.pdf
#
# CSV file created at: SL23-001012_1_371_clinical_report/SL23-001012_1_371_mutsumm.csv
#
# file name:  SL23-000963_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000963_1_371.pdf
#
# CSV file created at: SL23-000963_1_371_clinical_report/SL23-000963_1_371_mutsumm.csv
#
# file name:  SL23-000825_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000825_1_371.pdf
#
# CSV file created at: SL23-000825_1_371_clinical_report/SL23-000825_1_371_mutsumm.csv
#
# file name:  SL23-000708_1_371  file_path:  Searchlight Info/SearchlightReports/SL23-000708_1_371.pdf
#
# CSV file created at: SL23-000708_1_371_clinical_report/SL23-000708_1_371_mutsumm.csv
